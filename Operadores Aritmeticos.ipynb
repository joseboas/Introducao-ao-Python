# %% [markdown]
# **Exemplo de Operadores:**
# Soma: +;
#  Subtração: -;
#  Multiplicação: *;
#  Divisão: /;
#  Módulo:% (resto da divisão)
#  Potência ***

# %% [markdown]
# **Exemplos**

# %%
x = 3
y = 5
z = x + y
z

# %%
a = 3
a +=   6
a

# %%
c = 10
d = 20
e = 100
f = (c + d) * e / 100
f

# %%
#Multiplicando variáveis texto
g = 'e'
g *= 3
g

# %%
z = 4
z *= 2
z

# %% [markdown]
# **Divisão Inteira**

# %%
10 // 2

# %% [markdown]
# **Observação:  mesmo forçando a divisão inteiro se você usa um número float, retorna float**

# %%
6.0 // 2

# %%
6 // 2.0

# %% [markdown]
# **Outros operadores**

# %%
#resto da divisão ou módulo
5 % 2

# %%
#Potência
5**2

# %% [markdown]
# **Função Type: saber o tipo da variável ou  número**

# %%
a = 5.0
type(a)

# %%
type(5)

# %%
type('jose')

# %%
z = 'jose'
type(z)
