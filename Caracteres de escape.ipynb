# %% [markdown]
# **Caracteres de Escape**

# %%
print("Essa mensagem com  \n Teste")
# Out:
# Essa mensagem com
#  Teste

# %%
print("Essa mensagem com \r Teste")
# Out:
#  Teste

# %%
print("Essa mensagem com \t Teste")
# Out:
# Essa mensagem com 	 Teste

# %%
print("Essa mensagem com \' Teste")
# Out:
# Essa mensagem com ' Teste

# %%
print("Essa mensagem com \'' Teste")
# Out:
# Essa mensagem com '' Teste

# %%
print("Essa mensagem com \f Teste")
# Out:
# Essa mensagem com  Teste

# %%
print("Essa mensagem com \ Teste")
# Out:
# Essa mensagem com \ Teste
