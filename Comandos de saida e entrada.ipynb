# %% [markdown]
# **Comando de Saída "print"**

# %%
print('Este texto será impresso no console')
x = 4
y = 5
print(x)
print("Texto e duas variáveis", x , y)

# %%
print(f'Valor variável x = {x} e y = {y}')

# %%
print(f'Valor da soma x + y = {x+y}')

# %% [markdown]
# **Adicionando quebras**

# %%
print('Adicionando\n quebra\n de\n linha')

# %% [markdown]
# **Comando de entrada de dados "input"**

# %%
x = input('Informe um valor:')
print(f'Valor da variável digitada = {x}')
