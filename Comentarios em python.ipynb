# %% [markdown]
# **Comentários usando o #**

# %%
#Esta linha será comentada
print("Primeiro tipo de comentário")

# %% [markdown]
# **Comentárioas com aspas triplas**

# %%
''' 
Exemplo com aspas 
triplas texto que desaja 
comentar vai até aqui 
print("Inicício")
'''  
print('Fim')
# Out:
# Fim
