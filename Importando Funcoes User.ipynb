# %%
import funcoesUser as fuser

# %%
a = fuser.soma(10,5)
print(f'A soma de 10 + 5 = {a}')
# Out:
# A soma de 10 + 5 = 15

# %%
print(fuser.imprimeMensagem('Utilizando um método para imprimir uma mensagem'))
# Out:
# Utilizando um método para imprimir uma mensagem
# None
